# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('abc.csv', index_col =0)

# %%
pd.crosstab(index=data['volume'],columns='count,dropna=True')
# Out:
# col_0      count,dropna=True
# volume
# 0                        334
# 100                       29
# 200                       32
# 300                       21
# 400                       25
# ...                      ...
# 86264800                   1
# 97830800                   1
# 99322500                   1
# 144702800                  1
# 161555000                  1
#
# [4832 rows x 1 columns]

# %%
print(data.head())  
print(data.describe())
# Out:
#                  open       high        low      close   adjclose  volume  \
# date
# 2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000  106600
# 2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000  128700
# 2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001  103100
# 2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000  173600
# 2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000  137800
#
#            ticker  RSIadjclose15  RSIvolume15  RSIadjclose25  ...  high-15  \
# date                                                          ...
# 2022-01-03   ASLE            NaN          NaN            NaN  ...      NaN
# 2022-01-04   ASLE            NaN          NaN            NaN  ...      NaN
# 2022-01-05   ASLE            NaN          NaN            NaN  ...      NaN
# 2022-01-06   ASLE            NaN          NaN            NaN  ...      NaN
# ...

# %%
print(data.shape)
# Out:
# (7781, 1284)

# %%
print(data.isnull().sum())
# Out:
# open                  0
# high                  0
# low                   0
# close                 0
# adjclose              0
#                    ...
# stochastic-kd-15    587
# volumenrelativo     215
# diff                155
# INCREMENTO          155
# TARGET                0
# Length: 1284, dtype: int64

# %%
data['INCREMENTO'].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(x = "high", data=data)
# Out:
# <Axes: xlabel='high'>

# %%
print(data['MACDadjclose15'].value_counts())
# Out:
# MACDadjclose15
# -0.314072    1
# -0.040348    1
#  0.085602    1
#  0.117473    1
#  0.161533    1
#             ..
# -0.005752    1
# -0.005810    1
# -0.007770    1
# -0.009174    1
#  0.190223    1
# Name: count, Length: 7006, dtype: int64

# %%
plt.scatter(data['high'], data['low'])  
plt.xlabel('high value')
plt.ylabel('low value')
plt.title('Scatter Plot of high vs low')
plt.show()
